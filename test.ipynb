# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import torch 
print("PyTorch version:", torch.__version__)
x = torch.rand(5, 3)
print(x)
# Out:
# PyTorch version: 2.9.1
# tensor([[0.0324, 0.7928, 0.2394],
#         [0.2363, 0.4879, 0.8223],
#         [0.3023, 0.3232, 0.7932],
#         [0.3861, 0.4923, 0.6317],
#         [0.5469, 0.7816, 0.4238]])
